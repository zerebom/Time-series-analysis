# %%
import glob
import re
import pandas as pd

# %%
df1=pd.read_csv()

# %%
for file in glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\Abe_speech4\*.txt'):
    month=re.sub( '_[0-9].txt' ,'', file)
    month=re.sub( r'.+Abe_speech4\\' ,'', month)
#     month=re.sub('-01Prep.+', '' ,month)
    print(month)
# Out:
# 2012-10-01
# 2012-11-01
# 2013-01-01
# 2013-02-01
# 2013-02-01
# 2013-02-01
# 2013-02-01
# 2013-02-01
# 2013-02-01
# 2013-03-01
# 2013-03-01
# 2013-03-01
# 2013-03-01
# 2013-04-01
# 2013-04-01
# 2013-04-01
# 2013-04-01
# 2013-05-01
# 2013-05-01
# 2013-05-01
# 2013-05-01
# 2013-06-01
# 2013-10-01
# 2013-10-01
# 2013-11-01
# 2013-12-01
# 2014-01-01
# 2014-02-01
# 2014-02-01
# 2014-02-01
# 2014-02-01
# 2014-02-01
# 2014-03-01
# 2014-03-01
# 2014-03-01
# 2014-03-01
# 2014-04-01
# 2014-05-01
# 2014-05-01
# 2014-06-01
# 2014-07-01
# 2014-09-01
# 2014-10-01
# 2014-10-01
# 2014-10-01
# 2014-11-01
# 2015-01-01
# 2015-02-01
# 2015-02-01
# 2015-02-01
# 2015-02-01
# 2015-02-01
# 2015-02-01
# 2015-03-01
# 2015-03-01
# 2015-03-01
# 2015-03-01
# 2015-03-01
# 2015-04-01
# 2015-05-01
# 2015-05-01
# 2015-06-01
# 2015-06-01
# 2015-06-01
# 2015-07-01
# 2015-07-01
# 2015-07-01
# 2015-07-01
# 2015-08-01
# 2015-08-01
# 2015-08-01
# 2015-08-01
# 2015-09-01
# 2015-11-01
# 2016-01-01
# 2016-01-01
# ...

# %%
def make_lines2(fname_parsed):#ジェネレーター
    # MeCabfileが必要↑

    with open(fname_parsed) as file_parsed:       
# ,'r',errors='ignore',encoding='utf-8_sig'
        morphemes = []
        
 
        for line in file_parsed:
       
            cols = line.split('\t')
            if(len(cols) < 2):
                raise StopIteration     # 区切りがなければ終了
            # ここでリスト型になる↓   
            res_cols = cols[1].split(',')

            # 辞書作成、リストに追加
    
            # cols[0]=re.sub('.+　','',cols[0])  
            if  cols[0]!='\u3000':           
                morphemes.append(cols[0])

            # 品詞細分類1が'句点'なら文の終わりと判定
            if res_cols[1] == '句点':

                # morphemes.append(cols[0])
                # ↑これがあると。が二つになってしまう
                yield morphemes
                # print(morphemes)
                morphemes = []
