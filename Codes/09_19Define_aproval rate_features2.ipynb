# %% [markdown]
# # このコードの目的
#
# 支持率が伸びている/落ちているデータセットをサイズが同じになるように集積して、
# 特徴分析を行う
# データセットが同じになるようにするとき、前処理した後のtxtファイルで比較するほうがよい
# +
# 機械学習にかける
#
# 追加した点は、globとFor文を使って、同じことを二階しないようにした

# %%
from 過去のコード.Mecab_func import *
import glob
import re
import sys
import os
import pandas as pd
import numpy as np

# %%
#各フォルダのサイズを比較するコード
#普通にエクスプローラーで見ればいい説



def compare_datasize(folder_A,folder_B):
    file_list_A=glob.glob(folder_A)
    file_list_B=glob.glob(folder_B)    
    A_size=[]
    B_size=[]
    
    for file_A in file_list_A:
        A_size.append(os.path.getsize(file_A))
        
    for file_B in file_list_B:
        B_size.append(os.path.getsize(file_B))    
        
    return(A_size,B_size)


# KBを表示してくれる
def look_datasize(folder_A):
    file_list_A=glob.glob(folder_A)
    A_size=[]
    for file_A in file_list_A:
        A_size.append(0.001*round(os.path.getsize(file_A),-3))

    return(A_size)


look_datasize(r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\Abe_speech2\Prep/*.txt')

# %%
def Preprocessing(fname):
    Matubi=[]
    with open(fname,errors='ignore') as data_file:
                ftitle, fext = os.path.splitext(fname)
                fname_out=ftitle+'Prep.txt'
                #空白文字を削除する
                text_data=data_file.read()
                text_data=re.sub('.+　','',text_data)
                #改行で区切る
                text_data=re.sub('\n','',text_data)
                #句点で区切り、最後の要素を抜き取る
                text_data=text_data.split('。')
                with open(fname_out, mode='w',errors='ignore') as out_file:
                    for i,text in enumerate(text_data):
                        #読点以前を削除する
    #                     text=text.split('、')
                        #なぜか先頭に空白文字が入るので取り除く↓。
                        text=text.lstrip()
                        #読点以降のみが集まる↓
                        text+='。'
                        out_file.write(text)
                    

# new_mecab (r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\Abe_speech\2012-10-01.txt')    

# for file in glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\Abe_speech2/*'):
    Preprocessing(file)

# %%
# for file in glob.glob(r'C:/Users/icech/Desktop/share/Lab/2018_09_05/Docments/low_aproval_rate/*'):
#     ftitle, fext = os.path.splitext(file)
#     fname_out=ftitle+'.mecab'
#     to_mecab(file,fname_out)
    
# folder_list=['late_plus','late_minus','current_plus','current_','','',]    
    
# for file in glob.glob(r'C:/Users/icech/Desktop/share/Lab/2018_09_05/Docments/high_aproval_rate/*'):
#     ftitle, fext = os.path.splitext(file)
#     fname_out=ftitle+'.mecab'
#     to_mecab(file,fname_out)    

folders=glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\09_19\*')

#孫クラスのファイルをMecab化する
for folder in folders:
    files=glob.glob(folder+r'\*.txt')
    for file in files:
        ftitle, fext = os.path.splitext(file)
        fname_out=ftitle+'.mecab'
        to_mecab(file,fname_out)

# %%
def make_stopword():
    f = open("../docments/stopword.txt","r")
    list = []
    for x in f:
        list.append(x.rstrip("\n"))
        #以下のようにしてしまうと、改行コードがlistに入ってしまうため注意
        #list.append(x)
    f.close()
    return(list)

# %%
def new_count_morpheme(word_class,folder_path):
    for i,file in enumerate(glob.glob(folder_path+r'\*.mecab')):
        if i==9:
            print('next_folder')
            
        stopword=make_stopword()
        #語数カウンター
        for line in make_lines(file):
            for morpheme in line:
#                 if len(morpheme['base'])==1 or morpheme['base'] in stopword:
                if len(morpheme['base'])==1:
                    continue
                if morpheme['pos'] == word_class:
                    word_counter.update([morpheme['base']])
    return(word_counter)

# %%
#品詞ごとに語数をカウントするコード
# concatを使うことによって異なる長さのdfを結合している

copus_dict={}
word_classes=['形容詞','動詞','名詞','接続詞']
df2=pd.DataFrame()
for word_class in word_classes:
    df1=pd.DataFrame()
    word_counter = Counter()
#         copus_dict[word_class+'word']= new_count_morpheme(word_class,file)[0]
    copus_dict[word_class]= new_count_morpheme(word_class)[1]
    count_word ,count_cnt =zip(*copus_dict[word_class].most_common())
    df1[word_class]=count_word
    df1[word_class+'_cnt']=count_cnt
    df2=pd.concat([df2,df1],axis=1)
# Out:
# c:\users\icech\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: generator 'make_lines' raised StopIteration
# next_folder
# next_folder
# next_folder
# next_folder
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-a135c87cd74d> in <module>()
#      12         word_counter = Counter()
#      13     #         copus_dict[word_class+'word']= new_count_morpheme(word_class,file)[0]
# ---> 14         copus_dict[word_class]= new_count_morpheme(word_class,folder)
#      15         count_word,count_cnt =zip(*copus_dict[word_class].most_common())
#      16         df_tmp[word_class]=count_word
#
# <ipython-input-45-97ce012635f3> in new_count_morpheme(word_class, folder_path)
#       6         stopword=make_stopword()
#       7         #語数カウンター
# ----> 8         for line in make_lines(file):
#       9             for morpheme in line:
#      10                 if len(morpheme['base'])==1:# or morpheme['base'] in stopword
#
# ~\Desktop\share\Lab\2018_09_05\Codes\過去のコード\Mecab_func.py in make_lines(fname_parsed)
#     140
#     141             # 表層形はtab区切り、それ以外は','区切りでバラす
# --> 142             cols = line.split('\t')
#     143             if(len(cols) < 2):
#     144                 raise StopIteration     # 区切りがなければ終了
#
# KeyboardInterrupt:

# %%
#品詞ごとに語数をカウントするコード
# concatを使うことによって異なる長さのdfを結合している

copus_dict={}
word_classes=['形容詞','動詞','名詞','接続詞']
count_df=pd.DataFrame()
folders=glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_09_05\Docments\09_19\*')

for folder in folders:
    for word_class in word_classes:
        df_tmp=pd.DataFrame()
        word_counter = Counter()
        count_word ,count_cnt =zip(*new_count_morpheme(word_class,folder).most_common(200))
        df_tmp[word_class]=count_word
        df_tmp[word_class+'_cnt']=count_cnt
        count_df=pd.concat([count_df,df_tmp],axis=1)
        print(count_df)
#         print(tmp)
# Out:
# c:\users\icech\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: generator 'make_lines' raised StopIteration
# next_folder
#          形容詞  形容詞_cnt
# 0         ない     1834
# 1         いい      249
# 2         強い      225
# 3         高い      175
# 4        厳しい      167
# 5        大きい      153
# 6        やすい      121
# 7        新しい      108
# 8         多い      105
# 9         早い       90
# 10       力強い       88
# 11        よい       76
# 12        低い       68
# 13       難しい       65
# 14       幅広い       54
# 15        広い       48
# 16       正しい       47
# 17        良い       44
# 18        若い       33
# 19      よろしい       32
# 20       にくい       32
# 21        重い       31
# 22     ふさわしい       31
# 23       少ない       29
# 24        長い       27
# 25       美しい       26
# 26        深い       25
# 27        近い       25
# 28        短い       23
# 29     すばらしい       23
# ..       ...      ...
# 110   はかばかしい        1
# 111       白い        1
# 112      悲しい        1
# 113      険しい        1
# 114      からい        1
# 115     下らない        1
# 116    そぐわない        1
# 117       浅い        1
# 118      暖かい        1
# 119       暑い        1
# 120       寒い        1
# 121      しげい        1
# 122     言い難い        1
# 123     生々しい        1
# 124     恐ろしい        1
# 125      ぬるい        1
# 126      危ない        1
# 127       うい        1
# 128     軟らかい        1
# 129     やましい        1
# 130     ほど遠い        1
# 131    くだらない        1
# 132      黄色い        1
# 133    やわらかい        1
# 134    ありがたい        1
# 135       熱い        1
# 136    つまらない        1
# 137     真新しい        1
# 138      やさい        1
# 139  恩着せがましい        1
#
# [140 rows x 2 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt
# 0       ない   1834.0      する   18675
# 1       いい    249.0      いる    7078
# 2       強い    225.0      いく    5103
# 3       高い    175.0      ある    3985
# 4      厳しい    167.0      れる    3216
# 5      大きい    153.0      思う    3048
# 6      やすい    121.0      なる    3034
# 7      新しい    108.0      おる    2963
# 8       多い    105.0     考える    1844
# 9       早い     90.0      行う    1699
# 10     力強い     88.0     できる    1671
# 11      よい     76.0    いただく    1490
# 12      低い     68.0     まいる    1349
# 13     難しい     65.0   申し上げる    1195
# 14     幅広い     54.0      せる    1110
# 15      広い     48.0     進める    1048
# 16     正しい     47.0      くる     956
# 17      良い     44.0     られる     719
# 18      若い     33.0      言う     653
# 19    よろしい     32.0     向ける     618
# 20     にくい     32.0      持つ     570
# 21      重い     31.0    取り組む     542
# 22   ふさわしい     31.0      得る     488
# 23     少ない     29.0     含める     480
# 24      長い     27.0     いたす     460
# 25     美しい     26.0      図る     398
# 26      深い     25.0     つくる     394
# 27      近い     25.0      働く     383
# 28      短い     23.0    踏まえる     368
# 29   すばらしい     23.0      やる     345
# ..     ...      ...     ...     ...
# 170    NaN      NaN      会う      42
# 171    NaN      NaN    取り戻す      41
# 172    NaN      NaN      経る      41
# 173    NaN      NaN      残る      40
# 174    NaN      NaN    守り抜く      40
# 175    NaN      NaN     務める      40
# 176    NaN      NaN    引き継ぐ      40
# 177    NaN      NaN      輝く      39
# 178    NaN      NaN      減る      39
# 179    NaN      NaN      もつ      38
# 180    NaN      NaN  つくり上げる      38
# 181    NaN      NaN      闘う      38
# 182    NaN      NaN     かかる      37
# 183    NaN      NaN      選ぶ      37
# 184    NaN      NaN      みる      36
# 185    NaN      NaN     脅かす      36
# 186    NaN      NaN     持てる      35
# 187    NaN      NaN     めぐる      35
# 188    NaN      NaN      負う      34
# 189    NaN      NaN    あふれる      34
# 190    NaN      NaN      覆す      34
# 191    NaN      NaN      作る      33
# 192    NaN      NaN      歩む      33
# 193    NaN      NaN      打つ      33
# 194    NaN      NaN     避ける      32
# 195    NaN      NaN     なくす      32
# 196    NaN      NaN     調べる      32
# 197    NaN      NaN     控える      32
# 198    NaN      NaN      済む      32
# 199    NaN      NaN    とどまる      32
#
# [200 rows x 4 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt
# 0       ない   1834.0      する   18675   こと    9419
# 1       いい    249.0      いる    7078   わけ    4338
# 2       強い    225.0      いく    5103   よう    3813
# 3       高い    175.0      ある    3985   これ    3210
# 4      厳しい    167.0      れる    3216   それ    1741
# 5      大きい    153.0      思う    3048  ところ    1722
# 6      やすい    121.0      なる    3034   もの    1649
# 7      新しい    108.0      おる    2963   ため    1619
# 8       多い    105.0     考える    1844   日本    1058
# 9       早い     90.0      行う    1699   我々    1053
# 10     力強い     88.0     できる    1671   必要     977
# 11      よい     76.0    いただく    1490   議論     972
# 12      低い     68.0     まいる    1349   国民     887
# 13     難しい     65.0   申し上げる    1195  お尋ね     792
# 14     幅広い     54.0      せる    1110  我が国     790
# 15      広い     48.0     進める    1048   政府     727
# 16     正しい     47.0      くる     956   状況     666
# 17      良い     44.0     られる     719   重要     658
# 18      若い     33.0      言う     653   問題     657
# 19    よろしい     32.0     向ける     618  *\n     657
# 20     にくい     32.0      持つ     570   今後     631
# 21      重い     31.0    取り組む     542   経済     628
# 22   ふさわしい     31.0      得る     488   地域     627
# 23     少ない     29.0     含める     480   指摘     613
# 24      長い     27.0     いたす     460   支援     610
# 25     美しい     26.0      図る     398   対応     603
# 26      深い     25.0     つくる     394   委員     585
# 27      近い     25.0      働く     383   関係     572
# 28      短い     23.0    踏まえる     368   答弁     554
# 29   すばらしい     23.0      やる     345   改革     529
# ..     ...      ...     ...     ...  ...     ...
# 170    NaN      NaN      会う      42   ふう     166
# 171    NaN      NaN    取り戻す      41   海外     165
# 172    NaN      NaN      経る      41   発生     164
# 173    NaN      NaN      残る      40   貢献     163
# 174    NaN      NaN    守り抜く      40  仕組み     163
# 175    NaN      NaN     務める      40   具体     162
# 176    NaN      NaN    引き継ぐ      40   導入     162
# 177    NaN      NaN      輝く      39   年金     161
# 178    NaN      NaN      減る      39   行使     161
# 179    NaN      NaN      もつ      38   政権     160
# 180    NaN      NaN  つくり上げる      38   基準     160
# 181    NaN      NaN      闘う      38   お話     160
# 182    NaN      NaN     かかる      37   増加     159
# 183    NaN      NaN      選ぶ      37   事業     157
# 184    NaN      NaN      みる      36   一つ     156
# 185    NaN      NaN     脅かす      36   先般     155
# 186    NaN      NaN     持てる      35   介護     155
# 187    NaN      NaN     めぐる      35   教育     154
# 188    NaN      NaN      負う      34   税収     154
# 189    NaN      NaN    あふれる      34   合意     150
# 190    NaN      NaN      覆す      34   期待     149
# 191    NaN      NaN      作る      33   財政     147
# 192    NaN      NaN      歩む      33   与党     147
# 193    NaN      NaN      打つ      33   解決     146
# 194    NaN      NaN     避ける      32   加速     146
# 195    NaN      NaN     なくす      32   残念     146
# 196    NaN      NaN     調べる      32   前提     146
# 197    NaN      NaN     控える      32   目的     146
# 198    NaN      NaN      済む      32   人材     145
# 199    NaN      NaN    とどまる      32   体制     143
#
# [200 rows x 6 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0
# 15      広い     48.0     進める    1048   政府     727      実は     52.0
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0
# 17      良い     44.0     られる     719   重要     658      でも     43.0
# 18      若い     33.0      言う     653   問題     657     だから     34.0
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0
# 24      長い     27.0     いたす     460   支援     610      では     18.0
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0
# 26      深い     25.0     つくる     394   委員     585     それで     14.0
# 27      近い     25.0      働く     383   関係     572      又は     13.0
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0
# ..     ...      ...     ...     ...  ...     ...     ...      ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN
#
# [200 rows x 8 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt
# 0     1336.0
# 1      226.0
# 2      208.0
# 3      163.0
# 4      155.0
# 5      141.0
# 6      131.0
# 7       94.0
# 8       93.0
# 9       93.0
# 10      64.0
# 11      64.0
# 12      63.0
# 13      61.0
# 14      57.0
# 15      50.0
# 16      50.0
# 17      44.0
# 18      41.0
# 19      40.0
# 20      35.0
# 21      33.0
# 22      32.0
# 23      31.0
# 24      30.0
# 25      29.0
# 26      29.0
# 27      25.0
# 28      25.0
# 29      24.0
# ..       ...
# 170      NaN
# 171      NaN
# 172      NaN
# 173      NaN
# 174      NaN
# 175      NaN
# 176      NaN
# 177      NaN
# 178      NaN
# 179      NaN
# 180      NaN
# 181      NaN
# 182      NaN
# 183      NaN
# 184      NaN
# 185      NaN
# 186      NaN
# 187      NaN
# 188      NaN
# 189      NaN
# 190      NaN
# 191      NaN
# 192      NaN
# 193      NaN
# 194      NaN
# 195      NaN
# 196      NaN
# 197      NaN
# 198      NaN
# 199      NaN
#
# [200 rows x 10 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt     動詞  動詞_cnt
# 0     1336.0     する   14982
# 1      226.0     いる    5559
# 2      208.0     いく    4492
# 3      163.0     ある    2882
# 4      155.0     れる    2649
# 5      141.0     おる    2523
# 6      131.0     なる    2466
# 7       94.0     思う    2407
# 8       93.0    考える    1683
# 9       93.0     行う    1439
# 10      64.0    できる    1351
# 11      64.0   いただく    1346
# 12      63.0  申し上げる     963
# 13      61.0     せる     912
# 14      57.0     くる     857
# 15      50.0    まいる     798
# 16      50.0    進める     743
# 17      44.0    られる     584
# 18      41.0     言う     453
# 19      40.0   取り組む     436
# 20      35.0    いたす     409
# 21      33.0     持つ     384
# 22      32.0    向ける     382
# 23      31.0    つくる     361
# 24      30.0    含める     343
# 25      29.0     得る     327
# 26      29.0     守る     323
# 27      25.0     見る     316
# 28      25.0     図る     301
# 29      24.0     働く     290
# ..       ...    ...     ...
# 170      NaN    務める      32
# 171      NaN     戻る      32
# 172      NaN    付ける      32
# 173      NaN     移る      32
# 174      NaN    掛かる      31
# 175      NaN     負う      31
# 176      NaN     済む      31
# 177      NaN    終わる      31
# 178      NaN   取り戻す      30
# 179      NaN   見据える      30
# 180      NaN     防ぐ      30
# 181      NaN    持てる      30
# 182      NaN    捉える      29
# 183      NaN    高まる      29
# 184      NaN  受け止める      29
# 185      NaN     問う      28
# 186      NaN   守り抜く      28
# 187      NaN    始まる      28
# 188      NaN    広がる      28
# 189      NaN    増やす      28
# 190      NaN  義務付ける      28
# 191      NaN     結ぶ      28
# 192      NaN  受け入れる      27
# 193      NaN   切り開く      27
# 194      NaN   とどまる      27
# 195      NaN    伸びる      27
# 196      NaN    下げる      27
# 197      NaN    つける      26
# 198      NaN     打つ      26
# 199      NaN  受けとめる      26
#
# [200 rows x 12 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt     動詞  動詞_cnt    名詞  名詞_cnt
# 0     1336.0     する   14982    こと    7060
# 1      226.0     いる    5559    わけ    3929
# 2      208.0     いく    4492    これ    2991
# 3      163.0     ある    2882    よう    2953
# 4      155.0     れる    2649    もの    1599
# 5      141.0     おる    2523   ところ    1439
# 6      131.0     なる    2466    それ    1324
# 7       94.0     思う    2407    ため    1153
# 8       93.0    考える    1683   *\n    1004
# 9       93.0     行う    1439    議論     932
# 10      64.0    できる    1351    我々     878
# 11      64.0   いただく    1346    必要     840
# 12      63.0  申し上げる     963    日本     810
# 13      61.0     せる     912    政府     694
# 14      57.0     くる     857    国民     689
# 15      50.0    まいる     798   我が国     650
# 16      50.0    進める     743   お尋ね     565
# 17      44.0    られる     584    確保     562
# 18      41.0     言う     453    制度     543
# 19      40.0   取り組む     436    状況     522
# 20      35.0    いたす     409    支援     507
# 21      33.0     持つ     384    指摘     499
# 22      32.0    向ける     382    関係     488
# 23      31.0    つくる     361    経済     484
# 24      30.0    含める     343    今後     484
# 25      29.0     得る     327    重要     482
# 26      29.0     守る     323    委員     445
# 27      25.0     見る     316    答弁     441
# 28      25.0     図る     301    地域     436
# 29      24.0     働く     290    対応     431
# ..       ...    ...     ...   ...     ...
# 170      NaN    務める      32   見直し     138
# 171      NaN     戻る      32    発生     138
# 172      NaN    付ける      32    ふう     137
# 173      NaN     移る      32  サービス     137
# 174      NaN    掛かる      31    事態     136
# 175      NaN     負う      31    お話     135
# 176      NaN     済む      31    運用     135
# 177      NaN    終わる      31    役割     133
# 178      NaN   取り戻す      30   事業者     133
# 179      NaN   見据える      30   北朝鮮     129
# 180      NaN     防ぐ      30    残念     128
# 181      NaN    持てる      30    事業     128
# 182      NaN    捉える      29  そのため     127
# 183      NaN    高まる      29    意見     126
# 184      NaN  受け止める      29  安倍内閣     126
# 185      NaN     問う      28    評価     125
# 186      NaN   守り抜く      28    体制     125
# 187      NaN    始まる      28    国内     125
# 188      NaN    広がる      28    機能     124
# 189      NaN    増やす      28    投資     124
# 190      NaN  義務付ける      28  安全保障     123
# 191      NaN     結ぶ      28    情報     123
# 192      NaN  受け入れる      27    海外     123
# 193      NaN   切り開く      27    目的     123
# 194      NaN   とどまる      27    内容     122
# 195      NaN    伸びる      27    具体     122
# 196      NaN    下げる      27    女性     122
# 197      NaN    つける      26    拍手     121
# 198      NaN     打つ      26    提案     121
# 199      NaN  受けとめる      26    規制     121
#
# [200 rows x 14 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt     動詞  動詞_cnt    名詞  名詞_cnt     接続詞  接続詞_cnt
# 0     1336.0     する   14982    こと    7060     そして   1479.0
# 1      226.0     いる    5559    わけ    3929      また   1108.0
# 2      208.0     いく    4492    これ    2991     しかし    536.0
# 3      163.0     ある    2882    よう    2953    あるいは    491.0
# 4      155.0     れる    2649    もの    1599     そこで    390.0
# 5      141.0     おる    2523   ところ    1439     例えば    347.0
# 6      131.0     なる    2466    それ    1324      及び    191.0
# 7       94.0     思う    2407    ため    1153      かつ    172.0
# 8       93.0    考える    1683   *\n    1004     つまり    145.0
# 9       93.0     行う    1439    議論     932      なお    107.0
# 10      64.0    できる    1351    我々     878      一方    103.0
# 11      64.0   いただく    1346    必要     840      ただ     99.0
# 12      63.0  申し上げる     963    日本     810    そもそも     93.0
# 13      61.0     せる     912    政府     694     まずは     77.0
# 14      57.0     くる     857    国民     689   したがって     41.0
# 15      50.0    まいる     798   我が国     650     だから     40.0
# 16      50.0    進める     743   お尋ね     565      でも     33.0
# 17      44.0    られる     584    確保     562      実は     33.0
# 18      41.0     言う     453    制度     543   だからこそ     27.0
# 19      40.0   取り組む     436    状況     522      又は     27.0
# 20      35.0    いたす     409    支援     507      いや     21.0
# 21      33.0     持つ     384    指摘     499    すなわち     20.0
# 22      32.0    向ける     382    関係     488    それでも     19.0
# 23      31.0    つくる     361    経済     484  しかしながら     14.0
# 24      30.0    含める     343    今後     484     ただし     12.0
# 25      29.0     得る     327    重要     482    ちなみに     11.0
# 26      29.0     守る     323    委員     445    こうして     10.0
# 27      25.0     見る     316    答弁     441      では     10.0
# 28      25.0     図る     301    地域     436    それでは      9.0
# 29      24.0     働く     290    対応     431     しかも      8.0
# ..       ...    ...     ...   ...     ...     ...      ...
# 170      NaN    務める      32   見直し     138     NaN      NaN
# 171      NaN     戻る      32    発生     138     NaN      NaN
# 172      NaN    付ける      32    ふう     137     NaN      NaN
# 173      NaN     移る      32  サービス     137     NaN      NaN
# 174      NaN    掛かる      31    事態     136     NaN      NaN
# 175      NaN     負う      31    お話     135     NaN      NaN
# 176      NaN     済む      31    運用     135     NaN      NaN
# 177      NaN    終わる      31    役割     133     NaN      NaN
# 178      NaN   取り戻す      30   事業者     133     NaN      NaN
# 179      NaN   見据える      30   北朝鮮     129     NaN      NaN
# 180      NaN     防ぐ      30    残念     128     NaN      NaN
# 181      NaN    持てる      30    事業     128     NaN      NaN
# 182      NaN    捉える      29  そのため     127     NaN      NaN
# 183      NaN    高まる      29    意見     126     NaN      NaN
# 184      NaN  受け止める      29  安倍内閣     126     NaN      NaN
# 185      NaN     問う      28    評価     125     NaN      NaN
# 186      NaN   守り抜く      28    体制     125     NaN      NaN
# 187      NaN    始まる      28    国内     125     NaN      NaN
# 188      NaN    広がる      28    機能     124     NaN      NaN
# 189      NaN    増やす      28    投資     124     NaN      NaN
# 190      NaN  義務付ける      28  安全保障     123     NaN      NaN
# 191      NaN     結ぶ      28    情報     123     NaN      NaN
# 192      NaN  受け入れる      27    海外     123     NaN      NaN
# 193      NaN   切り開く      27    目的     123     NaN      NaN
# 194      NaN   とどまる      27    内容     122     NaN      NaN
# 195      NaN    伸びる      27    具体     122     NaN      NaN
# 196      NaN    下げる      27    女性     122     NaN      NaN
# 197      NaN    つける      26    拍手     121     NaN      NaN
# 198      NaN     打つ      26    提案     121     NaN      NaN
# 199      NaN  受けとめる      26    規制     121     NaN      NaN
#
# [200 rows x 16 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt     動詞  動詞_cnt    名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  形容詞_cnt
# 0     1336.0     する   14982    こと    7060     そして   1479.0     ない   1490.0
# 1      226.0     いる    5559    わけ    3929      また   1108.0     いい    248.0
# 2      208.0     いく    4492    これ    2991     しかし    536.0     高い    170.0
# 3      163.0     ある    2882    よう    2953    あるいは    491.0    大きい    154.0
# 4      155.0     れる    2649    もの    1599     そこで    390.0    厳しい    141.0
# 5      141.0     おる    2523   ところ    1439     例えば    347.0     強い    131.0
# 6      131.0     なる    2466    それ    1324      及び    191.0    新しい     89.0
# 7       94.0     思う    2407    ため    1153      かつ    172.0    やすい     88.0
# 8       93.0    考える    1683   *\n    1004     つまり    145.0     早い     79.0
# 9       93.0     行う    1439    議論     932      なお    107.0    難しい     77.0
# 10      64.0    できる    1351    我々     878      一方    103.0     長い     74.0
# 11      64.0   いただく    1346    必要     840      ただ     99.0     多い     63.0
# 12      63.0  申し上げる     963    日本     810    そもそも     93.0    幅広い     53.0
# 13      61.0     せる     912    政府     694     まずは     77.0     低い     52.0
# 14      57.0     くる     857    国民     689   したがって     41.0     よい     50.0
# 15      50.0    まいる     798   我が国     650     だから     40.0    力強い     48.0
# 16      50.0    進める     743   お尋ね     565      でも     33.0    正しい     39.0
# 17      44.0    られる     584    確保     562      実は     33.0     広い     36.0
# 18      41.0     言う     453    制度     543   だからこそ     27.0     深い     31.0
# 19      40.0   取り組む     436    状況     522      又は     27.0     近い     29.0
# 20      35.0    いたす     409    支援     507      いや     21.0   おかしい     29.0
# 21      33.0     持つ     384    指摘     499    すなわち     20.0  ふさわしい     28.0
# 22      32.0    向ける     382    関係     488    それでも     19.0     短い     27.0
# 23      31.0    つくる     361    経済     484  しかしながら     14.0   よろしい     26.0
# 24      30.0    含める     343    今後     484     ただし     12.0    美しい     26.0
# 25      29.0     得る     327    重要     482    ちなみに     11.0    にくい     24.0
# 26      29.0     守る     323    委員     445    こうして     10.0    少ない     23.0
# 27      25.0     見る     316    答弁     441      では     10.0     若い     23.0
# 28      25.0     図る     301    地域     436    それでは      9.0     重い     20.0
# 29      24.0     働く     290    対応     431     しかも      8.0     悪い     19.0
# ..       ...    ...     ...   ...     ...     ...      ...    ...      ...
# 170      NaN    務める      32   見直し     138     NaN      NaN    NaN      NaN
# 171      NaN     戻る      32    発生     138     NaN      NaN    NaN      NaN
# 172      NaN    付ける      32    ふう     137     NaN      NaN    NaN      NaN
# 173      NaN     移る      32  サービス     137     NaN      NaN    NaN      NaN
# 174      NaN    掛かる      31    事態     136     NaN      NaN    NaN      NaN
# 175      NaN     負う      31    お話     135     NaN      NaN    NaN      NaN
# 176      NaN     済む      31    運用     135     NaN      NaN    NaN      NaN
# 177      NaN    終わる      31    役割     133     NaN      NaN    NaN      NaN
# 178      NaN   取り戻す      30   事業者     133     NaN      NaN    NaN      NaN
# 179      NaN   見据える      30   北朝鮮     129     NaN      NaN    NaN      NaN
# 180      NaN     防ぐ      30    残念     128     NaN      NaN    NaN      NaN
# 181      NaN    持てる      30    事業     128     NaN      NaN    NaN      NaN
# 182      NaN    捉える      29  そのため     127     NaN      NaN    NaN      NaN
# 183      NaN    高まる      29    意見     126     NaN      NaN    NaN      NaN
# 184      NaN  受け止める      29  安倍内閣     126     NaN      NaN    NaN      NaN
# 185      NaN     問う      28    評価     125     NaN      NaN    NaN      NaN
# 186      NaN   守り抜く      28    体制     125     NaN      NaN    NaN      NaN
# 187      NaN    始まる      28    国内     125     NaN      NaN    NaN      NaN
# 188      NaN    広がる      28    機能     124     NaN      NaN    NaN      NaN
# ...
# 26      29.0   ...      対応     533    または     16.0    にくい     18.0     やる
# 27      25.0   ...      とき     513   それでも     15.0     良い     17.0     見る
# 28      25.0   ...      大臣     504   ちなみに     15.0   おかしい     17.0   踏まえる
# 29      24.0   ...      説明     479    よって     14.0   よろしい     17.0     示す
# ..       ...   ...     ...     ...    ...      ...    ...      ...    ...
# 170      NaN   ...      改正     152    NaN      NaN    NaN      NaN    言える
# 171      NaN   ...      物価     151    NaN      NaN    NaN      NaN    増やす
# 172      NaN   ...      提供     149    NaN      NaN    NaN      NaN    分かる
# 173      NaN   ...      出端     148    NaN      NaN    NaN      NaN     読む
# 174      NaN   ...      分野     147    NaN      NaN    NaN      NaN    深まる
# 175      NaN   ...      脱却     147    NaN      NaN    NaN      NaN    高まる
# 176      NaN   ...      自衛     147    NaN      NaN    NaN      NaN    かかる
# 177      NaN   ...      全力     146    NaN      NaN    NaN      NaN  受けとめる
# 178      NaN   ...      時間     145    NaN      NaN    NaN      NaN    くれる
# 179      NaN   ...      仕事     145    NaN      NaN    NaN      NaN   もたらす
# 180      NaN   ...     可能性     144    NaN      NaN    NaN      NaN   守り抜く
# 181      NaN   ...      効果     144    NaN      NaN    NaN      NaN   寄り添う
# 182      NaN   ...      全区     144    NaN      NaN    NaN      NaN    満たす
# 183      NaN   ...     明らか     144    NaN      NaN    NaN      NaN    迎える
# 184      NaN   ...      国際     143    NaN      NaN    NaN      NaN  受け止める
# 185      NaN   ...      活用     142    NaN      NaN    NaN      NaN     有す
# 186      NaN   ...      女性     141    NaN      NaN    NaN      NaN    持てる
# 187      NaN   ...    武力行使     140    NaN      NaN    NaN      NaN   取り巻く
# 188      NaN   ...      武力     140    NaN      NaN    NaN      NaN  働きかける
# 189      NaN   ...    そのため     138    NaN      NaN    NaN      NaN     及ぶ
# 190      NaN   ...      先般     138    NaN      NaN    NaN      NaN    始まる
# 191      NaN   ...      法律     138    NaN      NaN    NaN      NaN    遂げる
# 192      NaN   ...     委員会     138    NaN      NaN    NaN      NaN     移る
# 193      NaN   ...      復興     137    NaN      NaN    NaN      NaN    転じる
# 194      NaN   ...    首脳会談     137    NaN      NaN    NaN      NaN     買う
# 195      NaN   ...     PKO     137    NaN      NaN    NaN      NaN     輝く
# 196      NaN   ...      提案     137    NaN      NaN    NaN      NaN    つける
# 197      NaN   ...      総合     136    NaN      NaN    NaN      NaN     選ぶ
# 198      NaN   ...      合意     135    NaN      NaN    NaN      NaN     済む
# 199      NaN   ...      危険     135    NaN      NaN    NaN      NaN     問う
#
#      動詞_cnt    名詞  名詞_cnt
# 0     12366    こと    5890
# 1      4479    わけ    2780
# 2      3678    よう    2232
# 3      2367    これ    2151
# 4      2110    もの    1198
# 5      2083    それ    1080
# 6      2042   ところ    1007
# 7      1945   *\n     906
# 8      1394    ため     882
# 9      1111    我々     762
# 10     1083    議論     730
# 11      921    日本     655
# 12      872    必要     630
# 13      759    政府     560
# 14      756    国民     551
# 15      690   我が国     542
# 16      649    今後     490
# 17      522   お尋ね     465
# 18      406    経済     459
# 19      378    状況     425
# 20      361    確保     419
# 21      333    対応     406
# 22      323    実現     385
# 23      316    制度     380
# 24      293    委員     368
# 25      291    重要     358
# 26      259    米国     352
# 27      259    指摘     350
# 28      235    世界     347
# 29      222    支援     339
# ..      ...   ...     ...
# 170      29    維持     108
# 171      29    輸出     108
# 172      29    活動     107
# 173      28    昨年     107
# 174      27    介護     107
# 175      27   見直し     106
# 176      27  安倍内閣     106
# 177      27    名目     106
# 178      27    内容     105
# 179      27    意見     105
# 180      26    共有     105
# 181      26    憲法     104
# 182      25    仕事     103
# 183      25  消費税率     102
# 184      25    解決     102
# 185      25    能力     101
# 186      24    与党     101
# 187      24  軽減税率     101
# 188      24    開催     100
# 189      23    水準     100
# 190      23    評価     100
# 191      23    趣旨      99
# 192      23    合意      99
# 193      23    段階      99
# 194      23    体制      98
# 195      22    役割      97
# 196      22    成果      97
# 197      22    国々      97
# 198      22    未来      97
# 199      21    提供      96
#
# [200 rows x 46 columns]
# next_folder
#        形容詞  形容詞_cnt      動詞  動詞_cnt   名詞  名詞_cnt     接続詞  接続詞_cnt    形容詞  \
# 0       ない   1834.0      する   18675   こと    9419     そして   1625.0     ない
# 1       いい    249.0      いる    7078   わけ    4338      また   1371.0     いい
# 2       強い    225.0      いく    5103   よう    3813    あるいは    622.0     高い
# 3       高い    175.0      ある    3985   これ    3210     しかし    594.0    大きい
# 4      厳しい    167.0      れる    3216   それ    1741     そこで    424.0    厳しい
# 5      大きい    153.0      思う    3048  ところ    1722     例えば    414.0     強い
# 6      やすい    121.0      なる    3034   もの    1649      及び    237.0    新しい
# 7      新しい    108.0      おる    2963   ため    1619      かつ    195.0    やすい
# 8       多い    105.0     考える    1844   日本    1058     つまり    181.0     早い
# 9       早い     90.0      行う    1699   我々    1053      ただ    136.0     多い
# 10     力強い     88.0     できる    1671   必要     977    そもそも    135.0    幅広い
# 11      よい     76.0    いただく    1490   議論     972      一方    128.0     低い
# 12      低い     68.0     まいる    1349   国民     887     まずは    126.0    正しい
# 13     難しい     65.0   申し上げる    1195  お尋ね     792      なお    102.0     良い
# 14     幅広い     54.0      せる    1110  我が国     790   だからこそ     54.0     よい
# 15      広い     48.0     進める    1048   政府     727      実は     52.0    難しい
# 16     正しい     47.0      くる     956   状況     666   したがって     44.0    力強い
# 17      良い     44.0     られる     719   重要     658      でも     43.0     安い
# 18      若い     33.0      言う     653   問題     657     だから     34.0     長い
# 19    よろしい     32.0     向ける     618  *\n     657     しかも     32.0     広い
# 20     にくい     32.0      持つ     570   今後     631    すなわち     25.0     深い
# 21      重い     31.0    取り組む     542   経済     628      いや     24.0    にくい
# 22   ふさわしい     31.0      得る     488   地域     627     または     24.0     弱い
# 23     少ない     29.0     含める     480   指摘     613  しかしながら     22.0  ふさわしい
# 24      長い     27.0     いたす     460   支援     610      では     18.0   おかしい
# 25     美しい     26.0      図る     398   対応     603    ちなみに     15.0     若い
# 26      深い     25.0     つくる     394   委員     585     それで     14.0    少ない
# 27      近い     25.0      働く     383   関係     572      又は     13.0     重い
# 28      短い     23.0    踏まえる     368   答弁     554     ただし     13.0    美しい
# 29   すばらしい     23.0      やる     345   改革     529    それでも     10.0   よろしい
# ..     ...      ...     ...     ...  ...     ...     ...      ...    ...
# 170    NaN      NaN      会う      42   ふう     166     NaN      NaN    NaN
# 171    NaN      NaN    取り戻す      41   海外     165     NaN      NaN    NaN
# 172    NaN      NaN      経る      41   発生     164     NaN      NaN    NaN
# 173    NaN      NaN      残る      40   貢献     163     NaN      NaN    NaN
# 174    NaN      NaN    守り抜く      40  仕組み     163     NaN      NaN    NaN
# 175    NaN      NaN     務める      40   具体     162     NaN      NaN    NaN
# 176    NaN      NaN    引き継ぐ      40   導入     162     NaN      NaN    NaN
# 177    NaN      NaN      輝く      39   年金     161     NaN      NaN    NaN
# 178    NaN      NaN      減る      39   行使     161     NaN      NaN    NaN
# 179    NaN      NaN      もつ      38   政権     160     NaN      NaN    NaN
# 180    NaN      NaN  つくり上げる      38   基準     160     NaN      NaN    NaN
# 181    NaN      NaN      闘う      38   お話     160     NaN      NaN    NaN
# 182    NaN      NaN     かかる      37   増加     159     NaN      NaN    NaN
# 183    NaN      NaN      選ぶ      37   事業     157     NaN      NaN    NaN
# 184    NaN      NaN      みる      36   一つ     156     NaN      NaN    NaN
# 185    NaN      NaN     脅かす      36   先般     155     NaN      NaN    NaN
# 186    NaN      NaN     持てる      35   介護     155     NaN      NaN    NaN
# 187    NaN      NaN     めぐる      35   教育     154     NaN      NaN    NaN
# 188    NaN      NaN      負う      34   税収     154     NaN      NaN    NaN
# 189    NaN      NaN    あふれる      34   合意     150     NaN      NaN    NaN
# 190    NaN      NaN      覆す      34   期待     149     NaN      NaN    NaN
# 191    NaN      NaN      作る      33   財政     147     NaN      NaN    NaN
# 192    NaN      NaN      歩む      33   与党     147     NaN      NaN    NaN
# 193    NaN      NaN      打つ      33   解決     146     NaN      NaN    NaN
# 194    NaN      NaN     避ける      32   加速     146     NaN      NaN    NaN
# 195    NaN      NaN     なくす      32   残念     146     NaN      NaN    NaN
# 196    NaN      NaN     調べる      32   前提     146     NaN      NaN    NaN
# 197    NaN      NaN     控える      32   目的     146     NaN      NaN    NaN
# 198    NaN      NaN      済む      32   人材     145     NaN      NaN    NaN
# 199    NaN      NaN    とどまる      32   体制     143     NaN      NaN    NaN
#
#      形容詞_cnt   ...       接続詞  接続詞_cnt    形容詞  形容詞_cnt     動詞  動詞_cnt    名詞  \
# 0     1336.0   ...       そして   2292.0     ない   1212.0     する   12366    こと
# 1      226.0   ...        また   1348.0    厳しい    157.0     いる    4479    わけ
# 2      208.0   ...       しかし    808.0     高い    156.0     いく    3678    よう
# 3      163.0   ...      あるいは    692.0     いい    137.0     ある    2367    これ
# 4      155.0   ...       そこで    544.0     強い    129.0     れる    2110    もの
# 5      141.0   ...       例えば    505.0    大きい    119.0     おる    2083    それ
# 6      131.0   ...       つまり    345.0    新しい     90.0     なる    2042   ところ
# 7       94.0   ...        及び    234.0     早い     77.0     思う    1945   *\n
# 8       93.0   ...        かつ    210.0    やすい     68.0    考える    1394    ため
# 9       93.0   ...      そもそも    146.0    力強い     66.0     行う    1111    我々
# 10      64.0   ...        一方    145.0     多い     62.0    できる    1083    議論
# 11      64.0   ...        ただ    134.0     よい     58.0   いただく     921    日本
# 12      63.0   ...       まずは    124.0    幅広い     58.0  申し上げる     872    必要
# 13      61.0   ...     だからこそ     71.0     低い     53.0    まいる     759    政府
# 14      57.0   ...        なお     70.0    難しい     46.0     せる     756    国民
# 15      50.0   ...       だから     63.0    正しい     39.0    進める     690   我が国
# 16      50.0   ...        実は     62.0   粘り強い     36.0     くる     649    今後
# 17      44.0   ...     したがって     57.0    少ない     31.0    られる     522   お尋ね
# 18      41.0   ...      すなわち     52.0     長い     29.0     言う     406    経済
# 19      40.0   ...        でも     47.0  ふさわしい     26.0    向ける     378    状況
# 20      35.0   ...        いや     36.0     広い     21.0   取り組む     361    確保
# 21      33.0   ...        又は     34.0     重い     21.0     持つ     333    対応
# 22      32.0   ...        では     23.0     若い     19.0    つくる     323    実現
# 23      31.0   ...       しかも     22.0    美しい     18.0    いたす     316    制度
# 24      30.0   ...       それで     20.0  きめ細かい     18.0     得る     293    委員
# 25      29.0   ...        じゃ     16.0     深い     18.0    含める     291    重要
# 26      29.0   ...       または     16.0    にくい     18.0     やる     259    米国
# 27      25.0   ...      それでも     15.0     良い     17.0     見る     259    指摘
# 28      25.0   ...      ちなみに     15.0   おかしい     17.0   踏まえる     235    世界
# 29      24.0   ...       よって     14.0   よろしい     17.0     示す     222    支援
# ..       ...   ...       ...      ...    ...      ...    ...     ...   ...
# 170      NaN   ...       NaN      NaN    NaN      NaN    言える      29    維持
# 171      NaN   ...       NaN      NaN    NaN      NaN    増やす      29    輸出
# 172      NaN   ...       NaN      NaN    NaN      NaN    分かる      29    活動
# 173      NaN   ...       NaN      NaN    NaN      NaN     読む      28    昨年
# 174      NaN   ...       NaN      NaN    NaN      NaN    深まる      27    介護
# 175      NaN   ...       NaN      NaN    NaN      NaN    高まる      27   見直し
# 176      NaN   ...       NaN      NaN    NaN      NaN    かかる      27  安倍内閣
# 177      NaN   ...       NaN      NaN    NaN      NaN  受けとめる      27    名目
# 178      NaN   ...       NaN      NaN    NaN      NaN    くれる      27    内容
# 179      NaN   ...       NaN      NaN    NaN      NaN   もたらす      27    意見
# 180      NaN   ...       NaN      NaN    NaN      NaN   守り抜く      26    共有
# 181      NaN   ...       NaN      NaN    NaN      NaN   寄り添う      26    憲法
# 182      NaN   ...       NaN      NaN    NaN      NaN    満たす      25    仕事
# 183      NaN   ...       NaN      NaN    NaN      NaN    迎える      25  消費税率
# 184      NaN   ...       NaN      NaN    NaN      NaN  受け止める      25    解決
# 185      NaN   ...       NaN      NaN    NaN      NaN     有す      25    能力
# 186      NaN   ...       NaN      NaN    NaN      NaN    持てる      24    与党
# 187      NaN   ...       NaN      NaN    NaN      NaN   取り巻く      24  軽減税率
# 188      NaN   ...       NaN      NaN    NaN      NaN  働きかける      24    開催
# 189      NaN   ...       NaN      NaN    NaN      NaN     及ぶ      23    水準
# 190      NaN   ...       NaN      NaN    NaN      NaN    始まる      23    評価
# 191      NaN   ...       NaN      NaN    NaN      NaN    遂げる      23    趣旨
# 192      NaN   ...       NaN      NaN    NaN      NaN     移る      23    合意
# 193      NaN   ...       NaN      NaN    NaN      NaN    転じる      23    段階
# 194      NaN   ...       NaN      NaN    NaN      NaN     買う      23    体制
# 195      NaN   ...       NaN      NaN    NaN      NaN     輝く      22    役割
# 196      NaN   ...       NaN      NaN    NaN      NaN    つける      22    成果
# 197      NaN   ...       NaN      NaN    NaN      NaN     選ぶ      22    国々
# 198      NaN   ...       NaN      NaN    NaN      NaN     済む      22    未来
# 199      NaN   ...       NaN      NaN    NaN      NaN     問う      21    提供
#
#      名詞_cnt     接続詞  接続詞_cnt
# 0      5890     そして   1127.0
# 1      2780      また    856.0
# 2      2232     しかし    419.0
# 3      2151    あるいは    310.0
# 4      1198     例えば    281.0
# 5      1080     そこで    277.0
# 6      1007      かつ    162.0
# 7       906      及び    145.0
# 8       882     つまり    123.0
# 9       762     まずは     93.0
# 10      730      ただ     76.0
# 11      655      一方     74.0
# 12      630      なお     72.0
# 13      560    そもそも     59.0
# 14      551      実は     47.0
# 15      542   したがって     35.0
# 16      490   だからこそ     26.0
# 17      465  しかしながら     25.0
# 18      459      でも     20.0
# 19      425    すなわち     18.0
# 20      419     だから     18.0
# 21      406     または     15.0
# 22      385     しかも     15.0
# 23      380     それで     12.0
# 24      368     ただし     11.0
# 25      358      又は     10.0
# 26      352      では     10.0
# 27      350    ちなみに     10.0
# 28      347      いや     10.0
# 29      339     ゆえに      8.0
# ..      ...     ...      ...
# 170     108     NaN      NaN
# 171     108     NaN      NaN
# 172     107     NaN      NaN
# 173     107     NaN      NaN
# 174     107     NaN      NaN
# 175     106     NaN      NaN
# 176     106     NaN      NaN
# 177     106     NaN      NaN
# 178     105     NaN      NaN
# 179     105     NaN      NaN
# 180     105     NaN      NaN
# 181     104     NaN      NaN
# 182     103     NaN      NaN
# 183     102     NaN      NaN
# 184     102     NaN      NaN
# 185     101     NaN      NaN
# 186     101     NaN      NaN
# 187     101     NaN      NaN
# 188     100     NaN      NaN
# 189     100     NaN      NaN
# 190     100     NaN      NaN
# 191      99     NaN      NaN
# 192      99     NaN      NaN
# 193      99     NaN      NaN
# 194      98     NaN      NaN
# 195      97     NaN      NaN
# 196      97     NaN      NaN
# 197      97     NaN      NaN
# 198      97     NaN      NaN
# 199      96     NaN      NaN
#
# [200 rows x 48 columns]

# %%
count_df.to_csv('../non_stop_count_df.csv',encoding='shift_jis')
